# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
game_rating = {
	"Game": ["Dark Souls", "Dark Souls 2", "Dark Souls 3"],
	"Rating": [4, 4.3, 4.9]
}

df = pd.DataFrame(game_rating)
df
df.describe()
# Out:
#          Rating
# count  3.000000
# mean   4.400000
# std    0.458258
# min    4.000000
# 25%    4.150000
# 50%    4.300000
# 75%    4.600000
# max    4.900000

# %%
plt.bar(df["Game"], df["Rating"], color = 'blue')
plt.title("FromSoftware Game Ratings", color = "")
plt.xlabel("Game titles", color = "red")
plt.ylabel("Rating", color = "red")
plt.show()

# %%
sales = {
	"Year": [2022, 2023, 2024, 2025, 2026, 2027],
	"Sales": [200, 300, 400, 500, 600, 700]
}

df = pd.DataFrame(sales)
df
# Out:
#    Year  Sales
# 0  2022    200
# 1  2023    300
# 2  2024    400
# 3  2025    500
# 4  2026    600
# 5  2027    700

# %%
plt.bar(df["Year"], df["Sales"])
plt.title("Car sales")
plt.xlabel("Year")
plt.ylabel("Sales")
plt.show()

# %%
pie = np.array(df["Sales"])
max_sales = np.argmax(pie) # returns the index of the max sales

# %%
distinct_largest = True
for i in range(len(pie)):
	if (pie[i] == pie[max_sales] and i != max_sales):
		distinct_largest = False
		break

if (distinct_largest == True):
	highlight = [0.2 if sale == max_sales else 0 for sale in range(len(pie))]
else:
	highlight = [0 for sale in range(len(pie))]
print(highlight)
# Out:
# [0, 0, 0, 0, 0, 0.2]

# %%
plt.pie(pie, labels = df["Year"], explode = highlight)
plt.legend(title = "Car sales")

# %%
population_by_year = {
	"Year": [2022, 2023, 2024],
	"Population": [2000, 3000, 4000]
}

df = pd.DataFrame(population_by_year)
df

# %%
pie = np.array(df["Population"])
max_idx = np.argmax(pie)

distinct = True
for i in range(len(pie)):
	if (pie[i] == pie[max_idx] and i != max_idx):
		distinct = False
		break

if distinct == True:
	explode = [0.2 if i == max_idx else 0 for i in range(len(pie))]
else:
	explode = [0 for i in range(len(pie))]

# %%
plt.pie(pie, labels = df["Year"], explode = explode)
plt.legend(title = "Polulation of Red District by Year")
